# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 24.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 52.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 29.6 MB/s eta 0:00:00
# ...

# %%
# !pip install sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.2 MB/s eta 0:00:00
# ...

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.35.0

# %%
import sentencepiece
print(sentencepiece.__version__)
# Out:
# 0.1.99

# %%
# !pip install --upgrade transformers sentencepiece

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

# %%
# SentencePiece 설치 확인
try:
    import sentencepiece
except ImportError:
    raise ImportError("You need to have SentencePiece installed to use MBart50TokenizerFast.")

# %%
article_ko = "나는 어제 회사에 갔어."
article_en = "I eat lunch."

# %%
model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

# %%
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

# %%
tokenizer.src_lang = "ko_KN"  # 소스 언어 설정, 한국어
encoded_ko = tokenizer(article_ko, return_tensors="pt")  # 토큰화 및 인코딩
generated_tokens_ko = model.generate(
    **encoded_ko,
    forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"]  # 영어로 번역하도록 설정
)
translated_text_ko = tokenizer.batch_decode(generated_tokens_ko, skip_special_tokens=True)[0]  # 결과 디코딩
print("한국어에서 영어 번역:", translated_text_ko)
# Out:
# 한국어에서 영어 번역: I went to the company yesterday.
