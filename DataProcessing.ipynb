# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_pd = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ksl_sen_df.csv", encoding='UTF8')

# %%
train_pd
# Out:
#        folder_nums                ksl_sen
# 0                2        ['우산', '잃어버리다']
# 1                2  ['열쇠', '실종', '잃어버리다']
# 2                2        ['우산', '잃어버리다']
# 3                2           ['우산', '실종']
# 4                2           ['우산', '실종']
# ...            ...                    ...
# 57158            1         ['택시', '문자받다']
# 57159            1   ['택시', '문자보내다', '나']
# 57160            1         ['역무원', '부르다']
# 57161            1   ['택시', '문자보내다', '나']
# 57162            1         ['역무원', '부르다']
#
# [57163 rows x 2 columns]

# %%
train_pd.drop_duplicates(['ksl_sen'], ignore_index=True, inplace=True)

# %%
train_pd
# Out:
#       folder_nums                        ksl_sen
# 0               2                ['우산', '잃어버리다']
# 1               2          ['열쇠', '실종', '잃어버리다']
# 2               2                   ['우산', '실종']
# 3               2          ['우산', '없다', '잃어버리다']
# 4               2             ['우산', '없다', '실종']
# ...           ...                            ...
# 1108            6                   ['샛길', '다음']
# 1109            6  ['차내리다', '사거리', '건너다', '신호등']
# 1110            6             ['시간', '계산', '잘못']
# 1111            6            ['시간', '계산', '틀리다']
# 1112            7          ['내리다', '곳', ' 알려주다']
#
# [1113 rows x 2 columns]

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator

# Translator 클래스 객체 선언 (translator라는 변수명은 마음대로 정해주면 됨)
translator = Translator()

# %%
train_pd['esl_sen'] = ''

# %%
import re
result = re.sub("\'|[|]", "", train_pd.loc[0, 'ksl_sen'])
result = result[1:-1].split(',')
# Out:
# 우산
# str

# %%
# JSON 형태로 하려고 시도 중입니다. 데이터 불러와서 쓸 때 list of str 그자체로 불러올 수 있지 않을까 싶네요 json으로 하면.

import json
from collections import OrderedDict

json_data = OrderedDict()

# %%
for idx in train_pd.index:
  klist = re.sub("\'|[|]", "", train_pd.loc[0, 'ksl_sen'])[1:-1].split(',')
  elist = []
  for kword in klist:
    eword = translator.translate(kword)
    print(eword)
    elist.append(eword.text)
  print(elist)
  break
# Out:
# Translated(src=ko, dest=en, text=umbrella, pronunciation=None, extra_data="{'confiden...")
# Translated(src=ko, dest=en, text=lose, pronunciation=None, extra_data="{'confiden...")
# ['umbrella', 'lose']
